# %% [markdown]
# ```python
# balance = 1000
#
# def deposit(balance, amount):
#     balance += amount
#     return balance
#
# def withdraw(balance, amount):
#     if amount <= balance:
#         balance -= amount
#     return balance

# %%
balance = 1000

def deposit(balance, amount):
    balance += amount
    return balance

def withdraw(balance, amount):
    if amount <= balance:
        balance -= amount
    return balance

# %% [markdown]
# * can you answer whoes balance it is
# * at any point of time what is the balance of the owner

# %% [markdown]
# ```text
# ┌─────────────────────────┐
# │ DATA                    │
# │                         │
# │ owner                   │
# │ balance                 │
# │                         │
# │ OPERATIONS              │
# │                         │
# │ deposit()               │
# │ withdraw()              │
# └─────────────────────────┘
# ```

# %% [markdown]
# ```python
# class BankAccount:
#     pass
#
# account1 = BankAccount()
# account2 = BankAccount()

# %%
class BankAccount:
    pass

account1 = BankAccount()
account2 = BankAccount()

# %% [markdown]
# BankAccount → class\
# account1    → object\
# account2    → object

# %% [markdown]
# ### Attributes

# %% [markdown]
# ```python
# account1.owner = "Alice"
# account1.balance = 1000
#
# account2.owner = "Bob"
# account2.balance = 500

# %%
account1.owner = "Alice"
account1.balance = 1000

account2.owner = "Bob"
account2.balance = 500

# %% [markdown]
# ```python
# print(account1.owner)
# print(account2.owner)

# %%
print(account1.owner)
print(account2.owner)
print(account1.balance)
print(account2.balance)
# Out:
# Alice
# Bob
# 1000
# 500

# %% [markdown]
# #### Attributes are data associated with an object.
#
# ##################################################

# %% [markdown]
# ## Methods

# %% [markdown]
# ```python
# class BankAccount:
#
#     def deposit(self, amount):
#         self.balance += amount

# %%
class BankAccount:
    def __init__(self, account_num, owner, balance=0):
        self.account_num = account_num
        self.owner= owner
        self.balance = balance


    def __str__(self):
        return f"{self.account_num} | {self.owner}: ₹{self.balance}"

    def __eq__(self,other):
        return self.account_num == other.account_num
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            return True
        else:
            return False
        
    def deposit(self, amount):
        self.balance += amount

# %% [markdown]
# ```python
# account1.deposit(500)

# %%
account1 = BankAccount()
account1.balance = 1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 account1 = BankAccount()
#       2 account1.balance = 1000
#
# TypeError: BankAccount.__init__() missing 2 required positional arguments: 'account_num' and 'owner'

# %%
account1 = BankAccount

# %%
class BankAccount:
    
    def deposit(self, amount):
        self.balance += amount

# %%
account2 = BankAccount()
account2.balance = 1000

# %% [markdown]
# #### A method is a function that belongs to a class and defines behavior for its objects.

# %% [markdown]
# ```text
# Object
# │
# ├── attributes → what it has
# │
# └── methods    → what it does
# ```
#
# ##############################################################

# %% [markdown]
# ## Self

# %% [markdown]
# self refers to the object in consideration\
# (in the earlier case when we kdeposited 500 in account1 _self_ refers to account1)

# %% [markdown]
# ```python
# account1.balance

# %%
# account1.balance

# %% [markdown]
# ### create a new account and add name and balance to it

# %%
#code here

# %% [markdown]
# #### Create the object first and then manually initialize
# Do you see the problem here?

# %% [markdown]
# ```text
# __init__
# ```

# %% [markdown]
# ```python
# class BankAccount:
#
#     def __init__(self, owner, balance):
#         self.owner = owner
#         self.balance = balance

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance

# %% [markdown]
# ```python
# account1 = BankAccount("Alice", 1000)
# account2 = BankAccount("Bob", 500)

# %%
account1 = BankAccount("Alice", 1000)
account2 = BankAccount("Bob", 500)

# %% [markdown]
# can you print the accout1 here?
# ```python
# print(account1)

# %%
print(account1)

# %% [markdown]
# ### add this following method to the class definition
#
# ```python
#     def __str__(self):
#         return f"{self.owner}: ₹{self.balance}"
#
# now print(account1) again

# %%
def __str__(self):
        return f"{self.owner}: ₹{self.balance}"
        
print(account1)

# %% [markdown]
# ### What Python actually executes under the hood:
# ```text
# text_representation = account1.__str__()
# print(text_representation)

# %% [markdown]
# ```python
# class BankAccount:
#     def __init__(self, account_num, owner, balance=0):
#         self.account_num = account_num
#         self.owner= owner
#         self.balance = balance
#
#
#     def __str__(self):
#         return f"{self.account_num} | {self.owner}: ₹{self.balance}"

# %% [markdown]
# ```python
# account1 = BankAccount(101,'Alice',1000)
# account2 = BankAccount(102,'Bob',2000)
# account3 = BankAccount(101,'Alice',1000)
# print(account1)
# print(account2)
# print(account3)
#
#
# print(account1 == account3)

# %%
account1 = BankAccount(101,'Alice',1000)
account2 = BankAccount(102,'Bob',2000)
account3 = BankAccount(101,'Alice',1000)
print(account1)
print(account2)
print(account3)


print(account1 == account3)
# Out:
# 101 | Alice: ₹1000
# 102 | Bob: ₹2000
# 101 | Alice: ₹1000
# True

# %% [markdown]
# Add this method in the class  and then check the == again
# ```python
#     def __eq__(self,other):
#         return self.account_num == other.account_num

# %% [markdown]
# ####################################################\
# if you use dir()
# ```python
# print(dir(BankAccount))
# print(dir(account1))

# %%
print(dir(BankAccount))
print(dir(account1))

# account1.
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'deposit']
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'account_num', 'balance', 'deposit', 'owner']

# %% [markdown]
# ```python
# class BankAccount:
#     def __init__(self, account_num, owner, balance=0):
#         self.account_num = account_num
#         self.owner= owner
#         self.balance = balance

# %%
#code here

# %% [markdown]
# What if we want the account to deposit some amount?

# %% [markdown]
# self and amount have different roles.
#
# self → the object calling the method
# amount → information we provide to the method
#
#
# ```python
#     def deposit(self, amount):
#         self.balance += amount
#
# so account1.deposit(500)
# ```
# >self   → account1\
# >amount → 500

# %% [markdown]
# Add this method to the class
# ```python
# def withdraw(self, amount):
#     if amount <= self.balance:
#         self.balance -= amount
#         return True
#     else:
#         return False

# %% [markdown]
# ```python
# result = account1.withdraw(1000)
#
# print(result)
# print(account1.balance)

# %%
result = account1.withdraw(1000)

print(result)
print(account1.balance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 result = account1.withdraw(1000)
#       3 print(result)
#       4 print(account1.balance)
#
# AttributeError: 'BankAccount' object has no attribute 'withdraw'

# %% [markdown]
# ```python
# print(account1.balance)
#
# account1.deposit(500)
#
# print(account1.balance)
#
# account1.withdraw(200)
#
# print(account1.balance)

# %%
print(account1.balance)

account1.deposit(500)

print(account1.balance)

account1.withdraw(200)

print(account1.balance)
# Out:
# 1000
# 1500
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 7
#       3 account1.deposit(500)
#       5 print(account1.balance)
# ----> 7 account1.withdraw(200)
#       9 print(account1.balance)
#
# AttributeError: 'BankAccount' object has no attribute 'withdraw'

# %%
class BankAccount:


    def __init__(self,owner, balance):
        self.owner = owner
        self.balance= balance

    def deposit(self, amount):
        self.balance += amount

    def __str__(self):
        return f"{self.owner}: ₹{self.balance}"

# account1 = BankAccount()    
# account2 = BankAccount()

# account1.owner = "Alice"
# account1.balance = 1000

# account2.owner = "Bob"
# account2.balance = 500
account1 = BankAccount('Alice',1000)
account1.deposit(500)
account1.balance
# text=
text=account1.__str__()
text
# Out:
# 'Alice: ₹1500'

# %%
class BankAccount:
    def __init__(self, account_num, owner, balance=0):
        self.account_num = account_num
        self.owner= owner
        self.balance = balance


    def __str__(self):
        return f"{self.account_num} | {self.owner}: ₹{self.balance}"

    def __eq__(self,other):
        return self.account_num == other.account_num  

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            return True
        else:
            return False

# %%
class grandparents:
    partner = "alice"
    def compliment(self):
        print(f'hello beautiful {self.partner}')



class parents(grandparents):
    partner = 'helen'
    def compliment(self):
        super().compliment()
        print(f'hello gorgeous {self.partner}')
    pass


class children(parents):
    def compliment(self):
        super(parents,self).compliment()
        super().compliment()
        super().compliment()
        print('hey queen')
        return super().compliment()
    pass

# %%
g=grandparents()
g.compliment()
# Out:
# hello beautiful alice

# %%
p=parents()
p.compliment()
# Out:
# hello beautiful helen
# hello gorgeous helen

# %%
c = children()
c.compliment()
# Out:
# hello beautiful helen
# hello beautiful helen
# hello gorgeous helen
# hello beautiful helen
# hello gorgeous helen
# hey queen
# hello beautiful helen
# hello gorgeous helen
